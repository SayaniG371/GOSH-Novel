# %%
# %cd GOSH-novel
# !make clean && make
# Out:
# /content/GOSH
# mkdir -p execs
# nvcc -std=c++11 -Xcompiler -fopenmp -lgomp -O3   -D_BIG_GRAPHS  -I. -dc src/utils/sigmoid.cu -o sigmoid.o
# nvcc -x cu -std=c++11 -Xcompiler -fopenmp -lgomp -O3   -I. -dc src/utils/rand_helper.cpp -o rand_helper.o
# nvcc -std=c++11 -Xcompiler -fopenmp -lgomp -O3   -D_BIG_GRAPHS  -I. -dc src/utils/gpu_functions.cu -o gpu_functions.o
# nvcc -std=c++11 -Xcompiler -fopenmp -lgomp -O3   -D_BIG_GRAPHS  -I. -dc src/utils/big_graphs.cu -o big_graphs.o
# nvcc -std=c++11 -Xcompiler -fopenmp -lgomp -O3   -D_ARGPARSE -I. -dc src/main.cu -o main_argparse.o
# nvcc -std=c++11 -Xcompiler -fopenmp -lgomp -O3   sigmoid.o rand_helper.o gpu_functions.o big_graphs.o main_argparse.o -o execs/gosh.out
# nvcc -std=c++11 -Xcompiler -fopenmp -lgomp -O3   -I. -dc src/main.cu -o main.o
# nvcc -std=c++11 -Xcompiler -fopenmp -lgomp -O3   sigmoid.o rand_helper.o gpu_functions.o big_graphs.o main.o  -o execs/gosh_nargparse.out
# ...

# %%
# !execs/gosh.out --input-graph /content/LargeGraph.txt --output-embedding /content/LargeGraphEmb0.txt --directed 0 --epochs 100 --sampling-algorithm 1
# Out:
# Graph: /content/LargeGraph.txt
# Dimension: 128
# Negative samples: 3
# Epochs: 100
# Epoch batch size: 5
# Negative weight: 1.000000
# Device ID: 0
# Directed: 0
# Binary output: 0
# -------
# Sampling algorithm: Random-walks
# Alpha: 0
# Walk length: 10
# Augmentation distance: 3
# Sample pool size: 1000000
# -------
# Learning rate: 0.025000
# Learning rate decay strategy: 0
# -------
# Strategy: s-fast
# Smoothing Ratio: 0.500000
# -------
# Apply coarsening: 1
# Stopping Threshold: 1000
# Stopping Threshold Precision: 0.800000
# Matching Threshold: 400
# Minimum Number of Vertices in Graph: 100
# -------
# Number of embedding parts on the GPU: 3
# Number of sampling pools on the GPU: 4
# Sampling threads: 16
# Concurrent samplers: 4
# Sample pool sets: 2
# Task queue thread: 3
# Binary: false
# Output: /content/LargeGraphEmb0.txt
# NUM_BLOCKS: 8192 NUM_THREADS: 512
# WARP_SIZE: 32 WARPS_PER_BLOCK: 16 NUM_WARPS: 131072
# Device Number: 0
#   Device name: Tesla T4
# ...

# %%
# !head -10 /content/LargeGraphEmb0.txt
# Out:
# 4039 128
# ...
